# %%
import sys
import subprocess

for module in ["pandas", "seaborn", "matplotlib", "scikit-learn"]:
    try:
        __import__(module)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", module])

# %%
# Day 4: Applying Data Analytics Techniques for Visualization
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
# Load Iris Dataset
iris_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
iris = pd.read_csv(iris_url, header=None, names=columns)

# %%
# Task 1: K-Means Clustering
features = iris.drop("species", axis=1)
kmeans = KMeans(n_clusters=3)
iris["cluster"] = kmeans.fit_predict(features)
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue="cluster", palette="Set1")
plt.title("K-Means Clustering of Iris Data")
plt.show()

# %%
# Task 2: PCA for Dimensionality Reduction
pca = PCA(n_components=2)
iris_pca = pca.fit_transform(features)
iris["pca1"], iris["pca2"] = iris_pca[:, 0], iris_pca[:, 1]
sns.scatterplot(data=iris, x="pca1", y="pca2", hue="species", palette="Set2")
plt.title("PCA Visualization of Iris Data")
plt.show()
